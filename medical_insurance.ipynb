# %% [markdown]
# # Explorarea și Curățarea Datelor – Medical Insurance
#
# Acest notebook este un **mini-proiect de recapitulare pe date**. Lucrezi în perechi și **alegi singur(ă)** ce metode/ploturi sunt potrivite.
#
# **Scop:** să înțelegem ce factori pot influența `charges` (costuri asigurare).
# **Date:** `https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv`

# %% [markdown]
# ## 0) Setup rapid
# - Importă bibliotecile pe care le consideri necesare (pandas, numpy, matplotlib/plotly etc.).
# - Configurează opțiuni de afișare dacă vrei.

# %%
# scrie codul tău aici

# %% [markdown]
# ## 1) Înțelegerea datasetului
# - Încarcă datele în Pandas și inspectează câteva rânduri pentru a vedea cum arată.
# - **Explică forma și tipurile de date care se folosesc aici** (numeric vs categoric): ce înseamnă în context?
#
# **Scop:** să știm cu ce date lucrăm și cum trebuie pregătit setul pentru modelare.

# %%
# scrie codul tău aici

# %% [markdown]
# ## 2) Calitatea datelor
# - Verifică **valori lipsă**, **rânduri duplicate** și valori **aberante**.
# - Notează pe scurt potențialul impact asupra analizei.

# %%
# scrie codul tău aici

# %% [markdown]
# ## 3) Curățare și consistență
# - Creează o **copie de lucru** (ex. `df_clean`).
# - **Dacă este cazul**, uniformizează formatele (ex.: texte lowercase, spații în plus etc.) și tratează duplicatele.
# - **Dacă identifici** inconsistențe (categorii scrise diferit) sau înregistrări evident invalide, **decide** cum procedezi (păstrezi/elimini/corectezi) și **argumentează**.
#
# **Explică:** Ce (dacă) ai schimbat și de ce. Dacă nu ai schimbat nimic, justifică de ce setul este deja coerent.

# %%
# scrie codul tău aici

# %% [markdown]
# ## 4) Valorile lipsă (dacă există)
# - Arată câte valori lipsesc pe coloană.
# - Dacă există, alege o strategie (eliminare / completare cu medie/mediana/mod).
# - Aplică strategia aleasă.
#
# - Dacă nu există, ce metodă ai alege pentru o coloană (la alegere), dacă ar fi cazul?
#
# **Explică:** Cum ai decis metoda pentru fiecare tip de variabilă?

# %%
# scrie codul tău aici

# %% [markdown]
# ## 5) Explorarea distribuțiilor
# **Scop:** să înțelegi cum sunt răspândite valorile și dacă există extreme.
#
# **Task:**
# - Folosește o vizualizare care să te ajute să observi **cum sunt distribuite valorile** pentru variabilele numerice din setul tău.
# - Găsește o modalitate vizuală de a identifica **valorile foarte mari sau foarte mici** (outlieri).
#
# **Concluzie:** Care variabilă pare să aibă cea mai mare variație? Unde vezi valori neobișnuite?

# %%
# scrie codul tău aici

# %% [markdown]
# ## 6) Relații între variabile
# **Scop:** să descoperi legături între factori.
#
# **Task:**
# - Alege o reprezentare grafică potrivită pentru a vedea **cum se schimbă costurile (`charges`) în funcție de alți factori**.
# - Creează o vizualizare care să arate dacă **există o tendință clară între două variabile numerice** (când una crește, ce se întâmplă cu cealaltă?).
#
# **Concluzie:** Ce relații vizibile observi? Ce variabile par legate între ele?

# %%
# scrie codul tău aici

# %% [markdown]
# ## 7) Analiză pe variabile categorice
# **Scop:** să vezi dacă grupuri diferite au comportamente diferite.
#
# **Task:**
# - Creează o vizualizare care să arate **cum sunt distribuite persoanele între categorii**
# - Găsește o modalitate de a compara **valorile medii ale costurilor (`charges`) între aceste categorii**.
#
# **Concluzie:** Ce grupuri ies în evidență? Există diferențe majore între ele?

# %%
# scrie codul tău aici

# %% [markdown]
# ## 8) Relații multiple (mini-investigație)
# **Scop:** să explorezi combinații mai complexe de factori.
#
# **Task:**
# - Creează o vizualizare care te ajută să vezi **cum se combină mai multe variabile** din setul tău.
# - Folosește culoare, dimensiune sau alte elemente vizuale pentru a evidenția o a treia/patra variabilă.
#
# **Concluzie:** Ce combinații duc la cele mai mari costuri? Ce tipare apar?

# %%
# scrie codul tău aici

# %% [markdown]
# ## 9) Spre regresie (preview pentru cursul următor)
# - Propune o **ipoteză de model**: care 3–4 variabile ai folosi ca predictori pentru `charges` și de ce?
# - Scrie 4–5 rânduri cu raționamentul tău

# %% [markdown]
# > Scrie aici ipoteza ta 👇
